# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
import os

# %%
path='c:\\Users\\Lenovo\\异常\\' #放置998图片的路径
os.chdir(path)

# %%
os.getcwd() #现在的路径
#os.listdir(path)
# Out:
# 'c:\\Users\\Lenovo\\异常'

# %%
import skimage.io as io

# %%
#导入全部图片
str=path + '/*.tif'
img = io.ImageCollection(str)

# %%
print(len(img))
# Out:
# 15

# %%
plt.figure(figsize=(10, 10),dpi=100)
plt.imshow(img[0])

# %%
for j in range(0,15):
    gray_img = img[j][270:490, 530:730, 0] 
    labeled, nb_objects = ndimage.label(gray_img < 255)
    chr_img = labeled.copy()
    threshold = 1000
    for i in range(nb_objects+1):
        if len(np.where(chr_img == i)[0]) < threshold:
            chr_img[chr_img == i] = 0
    
    new_labeled, new_nb_objects = ndimage.label(chr_img) 

#slice1 = slice(290, 430, None)
#slice2 = slice(600, 750, None)
    
#slice_p = new_labeled[290:430, 600:750]

#slice_labeled, slice_nb_objects = ndimage.label(slice_p) 

#for i in range(slice_nb_objects+1):
    #if len(np.where(slice_labeled == i)[0]) < 2000:
        #slice_labeled[slice_labeled == i] = 0

    sample_chr9 = new_labeled == 1
    bbox = ndimage.find_objects(sample_chr9)
    slice1 = bbox[0][0]
    slice2 = bbox[0][1]
    a = img[j][270:490, 530:730, :]
    plt.figure(figsize=(0.09, 0.09), dpi=100)
    plt.imshow(a[slice1, slice2,:])
    plt.axis('off')
    

    path='c:\\Users\\Lenovo\\abnormal_100\\'
    os.chdir(path)
    plt.savefig(repr(j+1)+'.tif',dpi=1000)
    
    sample_chr22 = new_labeled == 2
    bbox = ndimage.find_objects(sample_chr22)
    slice1 = bbox[0][0]
    slice2 = bbox[0][1]
    a = img[j][270:490, 530:730, :]
    plt.figure(figsize=(0.09, 0.09), dpi=100)
    plt.imshow(a[slice1, slice2,:])
    plt.axis('off')
    
    path='c:\\Users\\Lenovo\\abnormal_100\\'
    os.chdir(path)
    plt.savefig(repr(j+1)+'re'+'.tif',dpi=1000)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-217-8198f993e197> in <module>
#       1 for j in range(0,998):
# ----> 2     gray_img = img[j][270:490, 530:730, 0]
#       3     labeled, nb_objects = ndimage.label(gray_img < 255)
#       4     chr_img = labeled.copy()
#       5     threshold = 1000
#
# ~\Anaconda3\lib\site-packages\skimage\io\collection.py in __getitem__(self, n)
#     246
#     247         if type(n) is int:
# --> 248             n = self._check_imgnum(n)
#     249             idx = n % len(self.data)
#     250
#
# ~\Anaconda3\lib\site-packages\skimage\io\collection.py in _check_imgnum(self, n)
#     303         else:
#     304             raise IndexError("There are only %s images in the collection"
# --> 305                              % num)
#     306         return n
#     307
#
# IndexError: There are only 15 images in the collection

# %%
    j=462
    gray_img = img[j][260:550, 530:730, 0]  #[300:520, 550:750, 0] 
    #[600:900, 650:850,0]
    plt.figure(figsize=(3.841, 7.195), dpi=100)
    plt.imshow(gray_img)

# %%
    labeled, nb_objects = ndimage.label(gray_img < 255)
    chr_img = labeled.copy()
    threshold = 3000
    for i in range(nb_objects+1):
        if len(np.where(chr_img == i)[0]) < threshold:
            chr_img[chr_img == i] = 0
    
    new_labeled, new_nb_objects = ndimage.label(chr_img)

# %%
plt.imshow(new_labeled)

# %%
    sample_chr9 = new_labeled == 1
    bbox = ndimage.find_objects(sample_chr9)
    slice1 = bbox[0][0]
    slice2 = bbox[0][1]
    a = img[j][260:550, 530:730, :]
    plt.figure(figsize=(0.09, 0.15), dpi=100)
    plt.imshow(a[slice1, slice2,:])

    path='c:\\Users\\Lenovo\\normal\\'
    os.chdir(path)
    plt.axis('off')
    
    plt.savefig(repr(j+1)+'.tif',dpi=1000)

# %%
    sample_chr9 = new_labeled == 2
    bbox = ndimage.find_objects(sample_chr9)
    slice1 = bbox[0][0]
    slice2 = bbox[0][1]
    a = img[j][260:550, 530:730, :]
    plt.figure(figsize=(0.09, 0.15), dpi=100)
    plt.imshow(a[slice1, slice2,:])

    path='c:\\Users\\Lenovo\\normal\\'
    os.chdir(path)
    plt.axis('off')
    
    plt.savefig(repr(j+1)+'re'+'.tif',dpi=1000)

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\sz\Chromosomes

# %%
os.chdir
# Out:
# <function nt.chdir(path)>

# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
import os

# %%
path='D:\\Learn\\大三下\\summer\\Chromosomes_anomaly'
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'D:\\Learn\\大三下\\summer\\Chromosomes_anomaly'

# %%
import skimage.io as io

# %%
str=path + '/*.tif'
img = io.ImageCollection(str)

# %%
print(len(img))
# Out:
# 199

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img[0])
